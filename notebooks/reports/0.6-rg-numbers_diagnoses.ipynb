# %% [markdown]
# ### Show case numbers of DSM-5 diagnoses

# %%
from pathlib import Path

# OPTIONAL: Load the "autoreload" extension so that code can change
# %load_ext autoreload

# OPTIONAL: always reload modules so that as you change code in src, it gets loaded
# %autoreload 2

import numpy as np
import pandas as pd

from src.data.preprocess_data import create_binary_diagnoses_df, select_one_child_per_family
from src.data.var_names import diagnoses
from src.definitions import REPO_ROOT, RAW_DATA_DIR, PROCESSED_DATA_DIR

# %%
import numpy as np
import pandas as pd

abcd_data_path=Path(RAW_DATA_DIR)
subindicators_table=pd.read_csv(RAW_DATA_DIR / 'subindicators_table.csv')

subindicators_table
# Out:
#                                              Diagnosis  \
# 0    Other Specified Neurodevelopmental Disorder Au...
# 1                            Major Depressive Disorder
# 2                            Major Depressive Disorder
# 3                            Major Depressive Disorder
# 4                            Major Depressive Disorder
# ..                                                 ...
# 116                                   Anorexia Nervosa
# 117                                    Bulimia Nervosa
# 118                                    Bulimia Nervosa
# 119                                    Bulimia Nervosa
# 120                                    Bulimia Nervosa
#
#                          Spec         Interview          File         Feature
# 0                     current  parent interview   abcd_ksad01  ksads_18_903_p
# 1                     current  parent interview   abcd_ksad01   ksads_1_840_p
# 2                        past  parent interview   abcd_ksad01   ksads_1_842_p
# 3                     current   youth interview  abcd_ksad501   ksads_1_840_t
# 4                        past   youth interview  abcd_ksad501   ksads_1_842_t
# ..                        ...               ...           ...             ...
# 116  past restricting subtype   youth interview  abcd_ksad501  ksads_13_934_t
# 117                   current  parent interview   abcd_ksad01  ksads_13_935_p
# 118                      past  parent interview   abcd_ksad01  ksads_13_936_p
# 119                   current   youth interview  abcd_ksad501  ksads_13_935_t
# 120                      past   youth interview  abcd_ksad501  ksads_13_936_t
#
# [121 rows x 5 columns]

# %%
import copy
from functools import partial


def create_binary_diagnoses_df_detailed(
    abcd_data_path:Path,
    subindicators_table:pd.DataFrame,
    or_rule:bool,
    and_rule:bool
):
    # we want to summarize Bipolar I and II Disorder
    subindicators_table_ = copy.deepcopy(subindicators_table)
    subindicators_table_ = subindicators_table_.replace(to_replace='Bipolar I Disorder', value='Bipolar Disorder')
    subindicators_table_ = subindicators_table_.replace(to_replace='Bipolar II Disorder', value='Bipolar Disorder')

    # open files
    opened_dfs = []
    for filename in subindicators_table_['File'].unique():
        
        columns = list(subindicators_table_[subindicators_table_['File'] == filename]['Feature']) + ['src_subject_id']
        new_file = pd.read_csv(abcd_data_path / f'{filename}.txt', sep='\t', skiprows=(1, 1))
        # we are only interested in the baseline assessment of the ABCD study
        new_file = new_file.loc[new_file['eventname'] == "baseline_year_1_arm_1"]
        # capitalize subject id to avoid false mismatches lateron
        new_file['src_subject_id'] = new_file['src_subject_id'].str.upper()
        # select only relevant columns and save to list
        new_file = new_file[columns]
        opened_dfs.append(new_file)
                
    # merge to one df
    raw_subindicators_df = opened_dfs[0]
    for df in opened_dfs[1:]:
        raw_subindicators_df = raw_subindicators_df.merge(right=df, how='outer', on='src_subject_id')
    raw_subindicators_df.index = raw_subindicators_df['src_subject_id']
    raw_subindicators_df = raw_subindicators_df.drop(columns=['src_subject_id'])
    
    # first, apply or-rule for labels 'within interviewees'
    # e.g. if MDD has been diagnosed either at present or in the past in only the youth interview,
    # the youth label is positive
    dict_series = {}
    for diagnosis in subindicators_table_['Diagnosis'].unique():
        for interviewee in ['parent', 'youth']:
            cols = subindicators_table_[
                (subindicators_table_['Diagnosis'] == diagnosis) & \
                (subindicators_table_['Interview'] == f'{interviewee} interview')
            ]['Feature']
            if len(cols) == 0:
                break
            summarize_or = partial(summarize, rule='or')
            dict_series[f'{diagnosis}_{interviewee}'] = raw_subindicators_df[cols].apply(summarize_or, axis=1)
    interviewee_labels_df = pd.DataFrame(dict_series)
    
    # summarize within-interviewee labels via and/or-rule
    dict_series = {}
    for diagnosis in subindicators_table_['Diagnosis'].unique():
        cols = [f'{diagnosis}_{interviewee}' for interviewee in ['parent', 'youth'] \
                if f'{diagnosis}_{interviewee}' in interviewee_labels_df.columns]
        if or_rule:
            summarize_or = partial(summarize, rule='or')
            dict_series[f'{diagnosis}_or_rule'] = interviewee_labels_df[cols].apply(summarize_or, axis=1)
        if and_rule:
            summarize_and = partial(summarize, rule='and')
            dict_series[f'{diagnosis}_and_rule'] = interviewee_labels_df[cols].apply(summarize_and, axis=1)
            
    return pd.DataFrame(dict_series)


def summarize(x:pd.Series, rule:str):
    assert rule == 'or' or rule == 'and', "rule keyword can only be 'or' or 'and'"
    if rule == 'or':
        # if at leats one positive value -> overall positive
        if 1.0 in x.values:
            return 1.0
        # if no positive value and at least one NaN -> we cannot know -> overall NaN
        elif x.isnull().any():
            return np.nan
        # if only negative values -> safely overall negative
        else:
            return 0.0
    elif rule == 'and':
        # if all values positive -> overall positive
        if x.all() and not x.isnull().any():
            return 1.0
        # if some values negative -> overall negative
        elif 0.0 in x.values:
            return 0.0
        # if only positive and NaN values -> we cannot know -> overall NaN
        else:
            return np.nan

# %%
binary_diagnoses = create_binary_diagnoses_df_detailed(RAW_DATA_DIR, subindicators_table, True, True)

# %%
binary_diagnoses
# Out:
#                   Other Specified Neurodevelopmental Disorder Autism Spectrum Disorder_or_rule  \
# src_subject_id
# NDAR_INV9EVRB30H                                                1.0
# NDAR_INV0AUBJJJ4                                                0.0
# NDAR_INV0CTJAAHC                                                0.0
# NDAR_INV0D83M5VE                                                1.0
# NDAR_INV0DKWEM1A                                                0.0
# ...                                                             ...
# NDAR_INVNTJF26D6                                                NaN
# NDAR_INVYN4CXY1B                                                NaN
# NDAR_INVBE7CJ121                                                NaN
# NDAR_INVFMCMJ0X2                                                NaN
# NDAR_INVNGJJTJJD                                                NaN
#
#                   Other Specified Neurodevelopmental Disorder Autism Spectrum Disorder_and_rule  \
# src_subject_id
# NDAR_INV9EVRB30H                                                1.0
# NDAR_INV0AUBJJJ4                                                0.0
# NDAR_INV0CTJAAHC                                                0.0
# NDAR_INV0D83M5VE                                                1.0
# NDAR_INV0DKWEM1A                                                0.0
# ...                                                             ...
# NDAR_INVNTJF26D6                                                NaN
# NDAR_INVYN4CXY1B                                                NaN
# NDAR_INVBE7CJ121                                                NaN
# NDAR_INVFMCMJ0X2                                                NaN
# NDAR_INVNGJJTJJD                                                NaN
#
#                   Major Depressive Disorder_or_rule  \
# src_subject_id
# NDAR_INV9EVRB30H                                0.0
# NDAR_INV0AUBJJJ4                                0.0
# NDAR_INV0CTJAAHC                                0.0
# NDAR_INV0D83M5VE                                0.0
# NDAR_INV0DKWEM1A                                0.0
# ...                                             ...
# NDAR_INVNTJF26D6                                NaN
# NDAR_INVYN4CXY1B                                NaN
# NDAR_INVBE7CJ121                                NaN
# NDAR_INVFMCMJ0X2                                NaN
# NDAR_INVNGJJTJJD                                NaN
#
#                   Major Depressive Disorder_and_rule  \
# src_subject_id
# NDAR_INV9EVRB30H                                 0.0
# NDAR_INV0AUBJJJ4                                 0.0
# NDAR_INV0CTJAAHC                                 0.0
# NDAR_INV0D83M5VE                                 0.0
# NDAR_INV0DKWEM1A                                 0.0
# ...                                              ...
# NDAR_INVNTJF26D6                                 0.0
# NDAR_INVYN4CXY1B                                 0.0
# NDAR_INVBE7CJ121                                 0.0
# NDAR_INVFMCMJ0X2                                 0.0
# NDAR_INVNGJJTJJD                                 0.0
#
#                   Persistent Depressive Disorder (Dysthymia)_or_rule  \
# src_subject_id
# NDAR_INV9EVRB30H                                                0.0
# NDAR_INV0AUBJJJ4                                                0.0
# NDAR_INV0CTJAAHC                                                0.0
# NDAR_INV0D83M5VE                                                0.0
# NDAR_INV0DKWEM1A                                                0.0
# ...                                                             ...
# NDAR_INVNTJF26D6                                                NaN
# NDAR_INVYN4CXY1B                                                NaN
# NDAR_INVBE7CJ121                                                NaN
# NDAR_INVFMCMJ0X2                                                NaN
# NDAR_INVNGJJTJJD                                                NaN
#
#                   Persistent Depressive Disorder (Dysthymia)_and_rule  \
# src_subject_id
# NDAR_INV9EVRB30H                                                0.0
# NDAR_INV0AUBJJJ4                                                0.0
# NDAR_INV0CTJAAHC                                                0.0
# NDAR_INV0D83M5VE                                                0.0
# NDAR_INV0DKWEM1A                                                0.0
# ...                                                             ...
# NDAR_INVNTJF26D6                                                0.0
# NDAR_INVYN4CXY1B                                                0.0
# NDAR_INVBE7CJ121                                                0.0
# NDAR_INVFMCMJ0X2                                                0.0
# NDAR_INVNGJJTJJD                                                0.0
#
#                   Bipolar Disorder_or_rule  Bipolar Disorder_and_rule  \
# src_subject_id
# NDAR_INV9EVRB30H                       0.0                        0.0
# NDAR_INV0AUBJJJ4                       0.0                        0.0
# NDAR_INV0CTJAAHC                       0.0                        0.0
# NDAR_INV0D83M5VE                       0.0                        0.0
# NDAR_INV0DKWEM1A                       0.0                        0.0
# ...                                    ...                        ...
# NDAR_INVNTJF26D6                       NaN                        0.0
# NDAR_INVYN4CXY1B                       NaN                        0.0
# NDAR_INVBE7CJ121                       NaN                        0.0
# NDAR_INVFMCMJ0X2                       NaN                        0.0
# NDAR_INVNGJJTJJD                       NaN                        0.0
#
#                   Psychotic Symptoms_or_rule  Psychotic Symptoms_and_rule  \
# src_subject_id
# NDAR_INV9EVRB30H                         0.0                          0.0
# NDAR_INV0AUBJJJ4                         0.0                          0.0
# NDAR_INV0CTJAAHC                         1.0                          1.0
# NDAR_INV0D83M5VE                         0.0                          0.0
# NDAR_INV0DKWEM1A                         0.0                          0.0
# ...                                      ...                          ...
# NDAR_INVNTJF26D6                         NaN                          NaN
# NDAR_INVYN4CXY1B                         NaN                          NaN
# NDAR_INVBE7CJ121                         NaN                          NaN
# NDAR_INVFMCMJ0X2                         NaN                          NaN
# NDAR_INVNGJJTJJD                         NaN                          NaN
#
#                   ...  Selective Mutism_or_rule  Selective Mutism_and_rule  \
# src_subject_id    ...
# NDAR_INV9EVRB30H  ...                       NaN                        NaN
# NDAR_INV0AUBJJJ4  ...                       NaN                        NaN
# NDAR_INV0CTJAAHC  ...                       NaN                        NaN
# NDAR_INV0D83M5VE  ...                       NaN                        NaN
# NDAR_INV0DKWEM1A  ...                       NaN                        NaN
# ...               ...                       ...                        ...
# NDAR_INVNTJF26D6  ...                       NaN                        NaN
# NDAR_INVYN4CXY1B  ...                       NaN                        NaN
# NDAR_INVBE7CJ121  ...                       NaN                        NaN
# NDAR_INVFMCMJ0X2  ...                       NaN                        NaN
# NDAR_INVNGJJTJJD  ...                       NaN                        NaN
#
#                   Specific Phobia_or_rule  Specific Phobia_and_rule  \
# src_subject_id
# NDAR_INV9EVRB30H                      1.0                       1.0
# NDAR_INV0AUBJJJ4                      0.0                       0.0
# NDAR_INV0CTJAAHC                      0.0                       0.0
# NDAR_INV0D83M5VE                      1.0                       1.0
# NDAR_INV0DKWEM1A                      1.0                       1.0
# ...                                   ...                       ...
# NDAR_INVNTJF26D6                      NaN                       NaN
# NDAR_INVYN4CXY1B                      NaN                       NaN
# NDAR_INVBE7CJ121                      NaN                       NaN
# NDAR_INVFMCMJ0X2                      NaN                       NaN
# NDAR_INVNGJJTJJD                      NaN                       NaN
#
#                   Binge-Eating Disorder_or_rule  \
# src_subject_id
# NDAR_INV9EVRB30H                            NaN
# NDAR_INV0AUBJJJ4                            NaN
# NDAR_INV0CTJAAHC                            NaN
# NDAR_INV0D83M5VE                            NaN
# NDAR_INV0DKWEM1A                            NaN
# ...                                         ...
# NDAR_INVNTJF26D6                            NaN
# NDAR_INVYN4CXY1B                            NaN
# NDAR_INVBE7CJ121                            NaN
# NDAR_INVFMCMJ0X2                            NaN
# NDAR_INVNGJJTJJD                            NaN
#
#                   Binge-Eating Disorder_and_rule  Anorexia Nervosa_or_rule  \
# src_subject_id
# NDAR_INV9EVRB30H                             0.0                       NaN
# NDAR_INV0AUBJJJ4                             0.0                       NaN
# NDAR_INV0CTJAAHC                             0.0                       NaN
# NDAR_INV0D83M5VE                             0.0                       NaN
# NDAR_INV0DKWEM1A                             0.0                       NaN
# ...                                          ...                       ...
# NDAR_INVNTJF26D6                             NaN                       NaN
# NDAR_INVYN4CXY1B                             NaN                       NaN
# NDAR_INVBE7CJ121                             NaN                       NaN
# NDAR_INVFMCMJ0X2                             NaN                       NaN
# NDAR_INVNGJJTJJD                             NaN                       NaN
#
#                   Anorexia Nervosa_and_rule  Bulimia Nervosa_or_rule  \
# src_subject_id
# NDAR_INV9EVRB30H                        0.0                      NaN
# NDAR_INV0AUBJJJ4                        0.0                      NaN
# NDAR_INV0CTJAAHC                        0.0                      NaN
# NDAR_INV0D83M5VE                        0.0                      NaN
# NDAR_INV0DKWEM1A                        0.0                      NaN
# ...                                     ...                      ...
# NDAR_INVNTJF26D6                        NaN                      NaN
# NDAR_INVYN4CXY1B                        NaN                      NaN
# NDAR_INVBE7CJ121                        NaN                      NaN
# NDAR_INVFMCMJ0X2                        NaN                      NaN
# NDAR_INVNGJJTJJD                        NaN                      NaN
#
#                   Bulimia Nervosa_and_rule
# src_subject_id
# NDAR_INV9EVRB30H                       0.0
# NDAR_INV0AUBJJJ4                       0.0
# NDAR_INV0CTJAAHC                       0.0
# NDAR_INV0D83M5VE                       0.0
# NDAR_INV0DKWEM1A                       0.0
# ...                                    ...
# NDAR_INVNTJF26D6                       NaN
# NDAR_INVYN4CXY1B                       NaN
# NDAR_INVBE7CJ121                       NaN
# NDAR_INVFMCMJ0X2                       NaN
# NDAR_INVNGJJTJJD                       NaN
#
# [11874 rows x 44 columns]

# %%
for diagnosis in subindicators_table['Diagnosis'].unique():
    if diagnosis == 'Bipolar I Disorder':
        diagnosis = 'Bipolar Disorder'
    if diagnosis == 'Bipolar II Disorder':
        continue
    print(diagnosis)
    # or rule
    col = f'{diagnosis}_or_rule'
    n_true = len(binary_diagnoses[binary_diagnoses[col] == 1.0])
    n_false = len(binary_diagnoses[binary_diagnoses[col] == 0.0])
    n_nan = len(binary_diagnoses[binary_diagnoses[col].isna()])
    print(f'  OR rule:  {n_true:5d} of {n_true + n_false:5d} positive ({100 * n_true/(n_true + n_false + 1e-10):.3f} %). {n_nan:5d} NaN values.')
    # and rule
    col = f'{diagnosis}_and_rule'
    n_true = len(binary_diagnoses[binary_diagnoses[col] == 1.0])
    n_false = len(binary_diagnoses[binary_diagnoses[col] == 0.0])
    n_nan = len(binary_diagnoses[binary_diagnoses[col].isna()])
    print(f'  AND rule: {n_true:5d} of {n_true + n_false:5d} positive ({100 * n_true/(n_true + n_false + 1e-10):.3f} %). {n_nan:5d} NaN values.')
# Out:
# Other Specified Neurodevelopmental Disorder Autism Spectrum Disorder
#   OR rule:   3247 of 11690 positive (27.776 %).   184 NaN values.
#   AND rule:  3247 of 11690 positive (27.776 %).   184 NaN values.
# Major Depressive Disorder
#   OR rule:    569 of 11661 positive (4.880 %).   213 NaN values.
#   AND rule:    23 of 11834 positive (0.194 %).    40 NaN values.
# Persistent Depressive Disorder (Dysthymia)
#   OR rule:     24 of 11660 positive (0.206 %).   214 NaN values.
#   AND rule:     0 of 11835 positive (0.000 %).    39 NaN values.
# Bipolar Disorder
#   OR rule:    878 of 11668 positive (7.525 %).   206 NaN values.
#   AND rule:    29 of 11827 positive (0.245 %).    47 NaN values.
# Psychotic Symptoms
#   OR rule:    315 of 11721 positive (2.687 %).   153 NaN values.
#   AND rule:   315 of 11721 positive (2.687 %).   153 NaN values.
# ADHD
#   OR rule:   2192 of 11701 positive (18.733 %).   173 NaN values.
#   AND rule:  2192 of 11701 positive (18.733 %).   173 NaN values.
# Oppositional Defiant Disorder
#   OR rule:   1667 of 11701 positive (14.247 %).   173 NaN values.
#   AND rule:  1667 of 11701 positive (14.247 %).   173 NaN values.
# Conduct Disorder
#   OR rule:    374 of 11701 positive (3.196 %).   173 NaN values.
#   AND rule:   374 of 11701 positive (3.196 %).   173 NaN values.
# PTSD
#   OR rule:    231 of 11690 positive (1.976 %).   184 NaN values.
#   AND rule:   231 of 11690 positive (1.976 %).   184 NaN values.
# Obsessive Compulsive Disorder
#   OR rule:   1099 of 11690 positive (9.401 %).   184 NaN values.
#   AND rule:  1099 of 11690 positive (9.401 %).   184 NaN values.
# Sleep Problems
#   OR rule:   2604 of 11690 positive (22.275 %).   184 NaN values.
#   AND rule:   304 of 11805 positive (2.575 %).    69 NaN values.
# Suicide Tendency
#   OR rule:   2225 of 11676 positive (19.056 %).   198 NaN values.
#   AND rule:   385 of 11819 positive (3.257 %).    55 NaN values.
# Generalized Anxiety Disorder
#   OR rule:    579 of 11663 positive (4.964 %).   211 NaN values.
#   AND rule:    13 of 11832 positive (0.110 %).    42 NaN values.
# Social Anxiety Disorder
#   OR rule:    619 of 11662 positive (5.308 %).   212 NaN values.
#   AND rule:    23 of 11833 positive (0.194 %).    41 NaN values.
# Panic Disorder
#   OR rule:     32 of 11690 positive (0.274 %).   184 NaN values.
#   AND rule:    32 of 11690 positive (0.274 %).   184 NaN values.
# Agoraphobia
#   OR rule:     55 of  6272 positive (0.877 %).  5602 NaN values.
#   AND rule:    55 of  6272 positive (0.877 %).  5602 NaN values.
# Separation Anxiety Disorder
#   OR rule:   1049 of 11710 positive (8.958 %).   164 NaN values.
#   AND rule:  1049 of 11710 positive (8.958 %).   164 NaN values.
# Selective Mutism
#   OR rule:      0 of     0 positive (0.000 %). 11874 NaN values.
#   AND rule:     0 of     0 positive (0.000 %). 11874 NaN values.
# Specific Phobia
#   OR rule:   3133 of 11690 positive (26.801 %).   184 NaN values.
#   AND rule:  3133 of 11690 positive (26.801 %).   184 NaN values.
# Binge-Eating Disorder
#   OR rule:     88 of    88 positive (100.000 %). 11786 NaN values.
#   AND rule:     0 of 11633 positive (0.000 %).   241 NaN values.
# Anorexia Nervosa
#   OR rule:      6 of     6 positive (100.000 %). 11868 NaN values.
#   AND rule:     0 of 11715 positive (0.000 %).   159 NaN values.
# Bulimia Nervosa
#   OR rule:      7 of     7 positive (100.000 %). 11867 NaN values.
#   AND rule:     0 of 11714 positive (0.000 %).   160 NaN values.

# %%
abcd_data = pd.read_csv(PROCESSED_DATA_DIR / 'abcd_data.csv')
abcd_data
# Out:
# C:\Users\Richard\AppData\Local\Temp\ipykernel_12820\3208408408.py:1: DtypeWarning: Columns (314,315) have mixed types. Specify dtype option on import or set low_memory=False.
#   abcd_data = pd.read_csv(PROCESSED_DATA_DIR / 'abcd_data.csv')
#         src_subject_id  age  female  married  race_ethnicity_Asian  \
# 0     NDAR_INV007W6H7B  126       0        1                     0
# 1     NDAR_INV00LJVZK2  121       0        0                     0
# 2     NDAR_INV00NPMHND  118       1        1                     0
# 3     NDAR_INV00R4TXET  114       1        1                     0
# 4     NDAR_INV00U4FTRU  130       1        0                     0
# ...                ...  ...     ...      ...                   ...
# 7183  NDAR_INVZZJ3A7BK  122       1        0                     0
# 7184  NDAR_INVZZL0VA2F  129       0        1                     0
# 7185  NDAR_INVZZLZCKAY  110       1        1                     0
# 7186  NDAR_INVZZZ2ALR6  120       1        1                     0
# 7187  NDAR_INVZZZNB0XC  108       1        1                     0
#
#       race_ethnicity_Black  race_ethnicity_Hispanic  race_ethnicity_Other  \
# 0                        0                        0                     0
# 1                        0                        0                     1
# 2                        0                        0                     0
# 3                        0                        0                     0
# 4                        0                        0                     1
# ...                    ...                      ...                   ...
# 7183                     0                        0                     0
# 7184                     1                        0                     0
# 7185                     0                        0                     0
# 7186                     0                        0                     1
# 7187                     0                        1                     0
#
#       race_ethnicity_White  high.educ_< HS Diploma  ...  \
# 0                        1                       0  ...
# 1                        0                       1  ...
# 2                        1                       0  ...
# 3                        1                       0  ...
# 4                        0                       0  ...
# ...                    ...                     ...  ...
# 7183                     1                       0  ...
# 7184                     0                       0  ...
# 7185                     1                       0  ...
# 7186                     0                       0  ...
# 7187                     0                       0  ...
#
#       Generalized Anxiety Disorder  Social Anxiety Disorder  Panic Disorder  \
# 0                             True                    False           False
# 1                            False                    False           False
# 2                             True                    False           False
# 3                            False                    False           False
# 4                             True                     True           False
# ...                            ...                      ...             ...
# 7183                         False                    False           False
# 7184                         False                    False           False
# 7185                         False                    False           False
# 7186                         False                    False           False
# 7187                         False                     True           False
#
#       Agoraphobia  Separation Anxiety Disorder  Selective Mutism  \
# 0           False                        False               NaN
# 1           False                        False               NaN
# 2           False                        False               NaN
# 3             NaN                        False               NaN
# 4             NaN                        False               NaN
# ...           ...                          ...               ...
# 7183        False                        False               NaN
# 7184        False                        False               NaN
# 7185        False                        False               NaN
# 7186        False                        False               NaN
# 7187        False                        False               NaN
#
#       Specific Phobia  Binge-Eating Disorder  Anorexia Nervosa  \
# 0               False                    NaN               NaN
# 1               False                    NaN               NaN
# 2                True                    NaN               NaN
# 3               False                    NaN               NaN
# 4               False                    NaN               NaN
# ...               ...                    ...               ...
# 7183             True                    NaN               NaN
# 7184            False                    NaN               NaN
# 7185             True                    NaN               NaN
# 7186             True                    NaN               NaN
# 7187            False                    NaN               NaN
#
#       Bulimia Nervosa
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 7183              NaN
# 7184              NaN
# 7185              NaN
# 7186              NaN
# 7187              NaN
#
# [7188 rows x 316 columns]

# %%
{col: col.replace('_or_rule', '') for col in binary_diagnoses.columns}
# Out:
# {'Other Specified Neurodevelopmental Disorder Autism Spectrum Disorder_or_rule': 'Other Specified Neurodevelopmental Disorder Autism Spectrum Disorder',
#  'Other Specified Neurodevelopmental Disorder Autism Spectrum Disorder_and_rule': 'Other Specified Neurodevelopmental Disorder Autism Spectrum Disorder_and_rule',
#  'Major Depressive Disorder_or_rule': 'Major Depressive Disorder',
#  'Major Depressive Disorder_and_rule': 'Major Depressive Disorder_and_rule',
#  'Persistent Depressive Disorder (Dysthymia)_or_rule': 'Persistent Depressive Disorder (Dysthymia)',
#  'Persistent Depressive Disorder (Dysthymia)_and_rule': 'Persistent Depressive Disorder (Dysthymia)_and_rule',
#  'Bipolar Disorder_or_rule': 'Bipolar Disorder',
#  'Bipolar Disorder_and_rule': 'Bipolar Disorder_and_rule',
#  'Psychotic Symptoms_or_rule': 'Psychotic Symptoms',
#  'Psychotic Symptoms_and_rule': 'Psychotic Symptoms_and_rule',
#  'ADHD_or_rule': 'ADHD',
#  'ADHD_and_rule': 'ADHD_and_rule',
#  'Oppositional Defiant Disorder_or_rule': 'Oppositional Defiant Disorder',
#  'Oppositional Defiant Disorder_and_rule': 'Oppositional Defiant Disorder_and_rule',
#  'Conduct Disorder_or_rule': 'Conduct Disorder',
#  'Conduct Disorder_and_rule': 'Conduct Disorder_and_rule',
#  'PTSD_or_rule': 'PTSD',
#  'PTSD_and_rule': 'PTSD_and_rule',
#  'Obsessive Compulsive Disorder_or_rule': 'Obsessive Compulsive Disorder',
#  'Obsessive Compulsive Disorder_and_rule': 'Obsessive Compulsive Disorder_and_rule',
#  'Sleep Problems_or_rule': 'Sleep Problems',
#  'Sleep Problems_and_rule': 'Sleep Problems_and_rule',
#  'Suicide Tendency_or_rule': 'Suicide Tendency',
#  'Suicide Tendency_and_rule': 'Suicide Tendency_and_rule',
#  'Generalized Anxiety Disorder_or_rule': 'Generalized Anxiety Disorder',
#  'Generalized Anxiety Disorder_and_rule': 'Generalized Anxiety Disorder_and_rule',
#  'Social Anxiety Disorder_or_rule': 'Social Anxiety Disorder',
#  'Social Anxiety Disorder_and_rule': 'Social Anxiety Disorder_and_rule',
#  'Panic Disorder_or_rule': 'Panic Disorder',
#  'Panic Disorder_and_rule': 'Panic Disorder_and_rule',
#  'Agoraphobia_or_rule': 'Agoraphobia',
#  'Agoraphobia_and_rule': 'Agoraphobia_and_rule',
#  'Separation Anxiety Disorder_or_rule': 'Separation Anxiety Disorder',
#  'Separation Anxiety Disorder_and_rule': 'Separation Anxiety Disorder_and_rule',
#  'Selective Mutism_or_rule': 'Selective Mutism',
#  'Selective Mutism_and_rule': 'Selective Mutism_and_rule',
#  'Specific Phobia_or_rule': 'Specific Phobia',
#  'Specific Phobia_and_rule': 'Specific Phobia_and_rule',
#  'Binge-Eating Disorder_or_rule': 'Binge-Eating Disorder',
#  'Binge-Eating Disorder_and_rule': 'Binge-Eating Disorder_and_rule',
#  'Anorexia Nervosa_or_rule': 'Anorexia Nervosa',
#  'Anorexia Nervosa_and_rule': 'Anorexia Nervosa_and_rule',
#  'Bulimia Nervosa_or_rule': 'Bulimia Nervosa',
#  'Bulimia Nervosa_and_rule': 'Bulimia Nervosa_and_rule'}

# %%
binary_diagnoses
# Out:
#                   Other Specified Neurodevelopmental Disorder Autism Spectrum Disorder_or_rule  \
# src_subject_id
# NDAR_INV9EVRB30H                                                1.0
# NDAR_INV0AUBJJJ4                                                0.0
# NDAR_INV0CTJAAHC                                                0.0
# NDAR_INV0D83M5VE                                                1.0
# NDAR_INV0DKWEM1A                                                0.0
# ...                                                             ...
# NDAR_INVNTJF26D6                                                NaN
# NDAR_INVYN4CXY1B                                                NaN
# NDAR_INVBE7CJ121                                                NaN
# NDAR_INVFMCMJ0X2                                                NaN
# NDAR_INVNGJJTJJD                                                NaN
#
#                   Other Specified Neurodevelopmental Disorder Autism Spectrum Disorder_and_rule  \
# src_subject_id
# NDAR_INV9EVRB30H                                                1.0
# NDAR_INV0AUBJJJ4                                                0.0
# NDAR_INV0CTJAAHC                                                0.0
# NDAR_INV0D83M5VE                                                1.0
# NDAR_INV0DKWEM1A                                                0.0
# ...                                                             ...
# NDAR_INVNTJF26D6                                                NaN
# NDAR_INVYN4CXY1B                                                NaN
# NDAR_INVBE7CJ121                                                NaN
# NDAR_INVFMCMJ0X2                                                NaN
# NDAR_INVNGJJTJJD                                                NaN
#
#                   Major Depressive Disorder_or_rule  \
# src_subject_id
# NDAR_INV9EVRB30H                                0.0
# NDAR_INV0AUBJJJ4                                0.0
# NDAR_INV0CTJAAHC                                0.0
# NDAR_INV0D83M5VE                                0.0
# NDAR_INV0DKWEM1A                                0.0
# ...                                             ...
# NDAR_INVNTJF26D6                                NaN
# NDAR_INVYN4CXY1B                                NaN
# NDAR_INVBE7CJ121                                NaN
# NDAR_INVFMCMJ0X2                                NaN
# NDAR_INVNGJJTJJD                                NaN
#
#                   Major Depressive Disorder_and_rule  \
# src_subject_id
# NDAR_INV9EVRB30H                                 0.0
# NDAR_INV0AUBJJJ4                                 0.0
# NDAR_INV0CTJAAHC                                 0.0
# NDAR_INV0D83M5VE                                 0.0
# NDAR_INV0DKWEM1A                                 0.0
# ...                                              ...
# NDAR_INVNTJF26D6                                 0.0
# NDAR_INVYN4CXY1B                                 0.0
# NDAR_INVBE7CJ121                                 0.0
# NDAR_INVFMCMJ0X2                                 0.0
# NDAR_INVNGJJTJJD                                 0.0
#
#                   Persistent Depressive Disorder (Dysthymia)_or_rule  \
# src_subject_id
# NDAR_INV9EVRB30H                                                0.0
# NDAR_INV0AUBJJJ4                                                0.0
# NDAR_INV0CTJAAHC                                                0.0
# NDAR_INV0D83M5VE                                                0.0
# NDAR_INV0DKWEM1A                                                0.0
# ...                                                             ...
# NDAR_INVNTJF26D6                                                NaN
# NDAR_INVYN4CXY1B                                                NaN
# NDAR_INVBE7CJ121                                                NaN
# NDAR_INVFMCMJ0X2                                                NaN
# NDAR_INVNGJJTJJD                                                NaN
#
#                   Persistent Depressive Disorder (Dysthymia)_and_rule  \
# src_subject_id
# NDAR_INV9EVRB30H                                                0.0
# NDAR_INV0AUBJJJ4                                                0.0
# NDAR_INV0CTJAAHC                                                0.0
# NDAR_INV0D83M5VE                                                0.0
# NDAR_INV0DKWEM1A                                                0.0
# ...                                                             ...
# NDAR_INVNTJF26D6                                                0.0
# NDAR_INVYN4CXY1B                                                0.0
# NDAR_INVBE7CJ121                                                0.0
# NDAR_INVFMCMJ0X2                                                0.0
# NDAR_INVNGJJTJJD                                                0.0
#
#                   Bipolar Disorder_or_rule  Bipolar Disorder_and_rule  \
# src_subject_id
# NDAR_INV9EVRB30H                       0.0                        0.0
# NDAR_INV0AUBJJJ4                       0.0                        0.0
# NDAR_INV0CTJAAHC                       0.0                        0.0
# NDAR_INV0D83M5VE                       0.0                        0.0
# NDAR_INV0DKWEM1A                       0.0                        0.0
# ...                                    ...                        ...
# NDAR_INVNTJF26D6                       NaN                        0.0
# NDAR_INVYN4CXY1B                       NaN                        0.0
# NDAR_INVBE7CJ121                       NaN                        0.0
# NDAR_INVFMCMJ0X2                       NaN                        0.0
# NDAR_INVNGJJTJJD                       NaN                        0.0
#
#                   Psychotic Symptoms_or_rule  Psychotic Symptoms_and_rule  \
# src_subject_id
# NDAR_INV9EVRB30H                         0.0                          0.0
# NDAR_INV0AUBJJJ4                         0.0                          0.0
# NDAR_INV0CTJAAHC                         1.0                          1.0
# NDAR_INV0D83M5VE                         0.0                          0.0
# NDAR_INV0DKWEM1A                         0.0                          0.0
# ...                                      ...                          ...
# NDAR_INVNTJF26D6                         NaN                          NaN
# NDAR_INVYN4CXY1B                         NaN                          NaN
# NDAR_INVBE7CJ121                         NaN                          NaN
# NDAR_INVFMCMJ0X2                         NaN                          NaN
# NDAR_INVNGJJTJJD                         NaN                          NaN
#
#                   ...  Selective Mutism_or_rule  Selective Mutism_and_rule  \
# src_subject_id    ...
# NDAR_INV9EVRB30H  ...                       NaN                        NaN
# NDAR_INV0AUBJJJ4  ...                       NaN                        NaN
# NDAR_INV0CTJAAHC  ...                       NaN                        NaN
# NDAR_INV0D83M5VE  ...                       NaN                        NaN
# NDAR_INV0DKWEM1A  ...                       NaN                        NaN
# ...               ...                       ...                        ...
# NDAR_INVNTJF26D6  ...                       NaN                        NaN
# NDAR_INVYN4CXY1B  ...                       NaN                        NaN
# NDAR_INVBE7CJ121  ...                       NaN                        NaN
# NDAR_INVFMCMJ0X2  ...                       NaN                        NaN
# NDAR_INVNGJJTJJD  ...                       NaN                        NaN
#
#                   Specific Phobia_or_rule  Specific Phobia_and_rule  \
# src_subject_id
# NDAR_INV9EVRB30H                      1.0                       1.0
# NDAR_INV0AUBJJJ4                      0.0                       0.0
# NDAR_INV0CTJAAHC                      0.0                       0.0
# NDAR_INV0D83M5VE                      1.0                       1.0
# NDAR_INV0DKWEM1A                      1.0                       1.0
# ...                                   ...                       ...
# NDAR_INVNTJF26D6                      NaN                       NaN
# NDAR_INVYN4CXY1B                      NaN                       NaN
# NDAR_INVBE7CJ121                      NaN                       NaN
# NDAR_INVFMCMJ0X2                      NaN                       NaN
# NDAR_INVNGJJTJJD                      NaN                       NaN
#
#                   Binge-Eating Disorder_or_rule  \
# src_subject_id
# NDAR_INV9EVRB30H                            NaN
# NDAR_INV0AUBJJJ4                            NaN
# NDAR_INV0CTJAAHC                            NaN
# NDAR_INV0D83M5VE                            NaN
# NDAR_INV0DKWEM1A                            NaN
# ...                                         ...
# NDAR_INVNTJF26D6                            NaN
# NDAR_INVYN4CXY1B                            NaN
# NDAR_INVBE7CJ121                            NaN
# NDAR_INVFMCMJ0X2                            NaN
# NDAR_INVNGJJTJJD                            NaN
#
#                   Binge-Eating Disorder_and_rule  Anorexia Nervosa_or_rule  \
# src_subject_id
# NDAR_INV9EVRB30H                             0.0                       NaN
# NDAR_INV0AUBJJJ4                             0.0                       NaN
# NDAR_INV0CTJAAHC                             0.0                       NaN
# NDAR_INV0D83M5VE                             0.0                       NaN
# NDAR_INV0DKWEM1A                             0.0                       NaN
# ...                                          ...                       ...
# NDAR_INVNTJF26D6                             NaN                       NaN
# NDAR_INVYN4CXY1B                             NaN                       NaN
# NDAR_INVBE7CJ121                             NaN                       NaN
# NDAR_INVFMCMJ0X2                             NaN                       NaN
# NDAR_INVNGJJTJJD                             NaN                       NaN
#
#                   Anorexia Nervosa_and_rule  Bulimia Nervosa_or_rule  \
# src_subject_id
# NDAR_INV9EVRB30H                        0.0                      NaN
# NDAR_INV0AUBJJJ4                        0.0                      NaN
# NDAR_INV0CTJAAHC                        0.0                      NaN
# NDAR_INV0D83M5VE                        0.0                      NaN
# NDAR_INV0DKWEM1A                        0.0                      NaN
# ...                                     ...                      ...
# NDAR_INVNTJF26D6                        NaN                      NaN
# NDAR_INVYN4CXY1B                        NaN                      NaN
# NDAR_INVBE7CJ121                        NaN                      NaN
# NDAR_INVFMCMJ0X2                        NaN                      NaN
# NDAR_INVNGJJTJJD                        NaN                      NaN
#
#                   Bulimia Nervosa_and_rule
# src_subject_id
# NDAR_INV9EVRB30H                       0.0
# NDAR_INV0AUBJJJ4                       0.0
# NDAR_INV0CTJAAHC                       0.0
# NDAR_INV0D83M5VE                       0.0
# NDAR_INV0DKWEM1A                       0.0
# ...                                    ...
# NDAR_INVNTJF26D6                       NaN
# NDAR_INVYN4CXY1B                       NaN
# NDAR_INVBE7CJ121                       NaN
# NDAR_INVFMCMJ0X2                       NaN
# NDAR_INVNGJJTJJD                       NaN
#
# [11874 rows x 44 columns]

# %%
binary_diagnoses_2 = binary_diagnoses.loc[abcd_data['src_subject_id']]

# %%
binary_diagnoses_2
# Out:
#                   Other Specified Neurodevelopmental Disorder Autism Spectrum Disorder_or_rule  \
# src_subject_id
# NDAR_INV007W6H7B                                                0.0
# NDAR_INV00LJVZK2                                                1.0
# NDAR_INV00NPMHND                                                0.0
# NDAR_INV00R4TXET                                                1.0
# NDAR_INV00U4FTRU                                                1.0
# ...                                                             ...
# NDAR_INVZZJ3A7BK                                                0.0
# NDAR_INVZZL0VA2F                                                0.0
# NDAR_INVZZLZCKAY                                                1.0
# NDAR_INVZZZ2ALR6                                                1.0
# NDAR_INVZZZNB0XC                                                0.0
#
#                   Other Specified Neurodevelopmental Disorder Autism Spectrum Disorder_and_rule  \
# src_subject_id
# NDAR_INV007W6H7B                                                0.0
# NDAR_INV00LJVZK2                                                1.0
# NDAR_INV00NPMHND                                                0.0
# NDAR_INV00R4TXET                                                1.0
# NDAR_INV00U4FTRU                                                1.0
# ...                                                             ...
# NDAR_INVZZJ3A7BK                                                0.0
# NDAR_INVZZL0VA2F                                                0.0
# NDAR_INVZZLZCKAY                                                1.0
# NDAR_INVZZZ2ALR6                                                1.0
# NDAR_INVZZZNB0XC                                                0.0
#
#                   Major Depressive Disorder_or_rule  \
# src_subject_id
# NDAR_INV007W6H7B                                0.0
# NDAR_INV00LJVZK2                                0.0
# NDAR_INV00NPMHND                                0.0
# NDAR_INV00R4TXET                                0.0
# NDAR_INV00U4FTRU                                0.0
# ...                                             ...
# NDAR_INVZZJ3A7BK                                0.0
# NDAR_INVZZL0VA2F                                0.0
# NDAR_INVZZLZCKAY                                0.0
# NDAR_INVZZZ2ALR6                                0.0
# NDAR_INVZZZNB0XC                                0.0
#
#                   Major Depressive Disorder_and_rule  \
# src_subject_id
# NDAR_INV007W6H7B                                 0.0
# NDAR_INV00LJVZK2                                 0.0
# NDAR_INV00NPMHND                                 0.0
# NDAR_INV00R4TXET                                 0.0
# NDAR_INV00U4FTRU                                 0.0
# ...                                              ...
# NDAR_INVZZJ3A7BK                                 0.0
# NDAR_INVZZL0VA2F                                 0.0
# NDAR_INVZZLZCKAY                                 0.0
# NDAR_INVZZZ2ALR6                                 0.0
# NDAR_INVZZZNB0XC                                 0.0
#
#                   Persistent Depressive Disorder (Dysthymia)_or_rule  \
# src_subject_id
# NDAR_INV007W6H7B                                                0.0
# NDAR_INV00LJVZK2                                                0.0
# NDAR_INV00NPMHND                                                0.0
# NDAR_INV00R4TXET                                                0.0
# NDAR_INV00U4FTRU                                                0.0
# ...                                                             ...
# NDAR_INVZZJ3A7BK                                                0.0
# NDAR_INVZZL0VA2F                                                0.0
# NDAR_INVZZLZCKAY                                                0.0
# NDAR_INVZZZ2ALR6                                                0.0
# NDAR_INVZZZNB0XC                                                0.0
#
#                   Persistent Depressive Disorder (Dysthymia)_and_rule  \
# src_subject_id
# NDAR_INV007W6H7B                                                0.0
# NDAR_INV00LJVZK2                                                0.0
# NDAR_INV00NPMHND                                                0.0
# NDAR_INV00R4TXET                                                0.0
# NDAR_INV00U4FTRU                                                0.0
# ...                                                             ...
# NDAR_INVZZJ3A7BK                                                0.0
# NDAR_INVZZL0VA2F                                                0.0
# NDAR_INVZZLZCKAY                                                0.0
# NDAR_INVZZZ2ALR6                                                0.0
# NDAR_INVZZZNB0XC                                                0.0
#
#                   Bipolar Disorder_or_rule  Bipolar Disorder_and_rule  \
# src_subject_id
# NDAR_INV007W6H7B                       0.0                        0.0
# NDAR_INV00LJVZK2                       1.0                        0.0
# NDAR_INV00NPMHND                       0.0                        0.0
# NDAR_INV00R4TXET                       0.0                        0.0
# NDAR_INV00U4FTRU                       1.0                        1.0
# ...                                    ...                        ...
# NDAR_INVZZJ3A7BK                       0.0                        0.0
# NDAR_INVZZL0VA2F                       0.0                        0.0
# NDAR_INVZZLZCKAY                       0.0                        0.0
# NDAR_INVZZZ2ALR6                       0.0                        0.0
# NDAR_INVZZZNB0XC                       1.0                        0.0
#
#                   Psychotic Symptoms_or_rule  Psychotic Symptoms_and_rule  \
# src_subject_id
# NDAR_INV007W6H7B                         0.0                          0.0
# NDAR_INV00LJVZK2                         0.0                          0.0
# NDAR_INV00NPMHND                         0.0                          0.0
# NDAR_INV00R4TXET                         0.0                          0.0
# NDAR_INV00U4FTRU                         0.0                          0.0
# ...                                      ...                          ...
# NDAR_INVZZJ3A7BK                         0.0                          0.0
# NDAR_INVZZL0VA2F                         0.0                          0.0
# NDAR_INVZZLZCKAY                         1.0                          1.0
# NDAR_INVZZZ2ALR6                         0.0                          0.0
# NDAR_INVZZZNB0XC                         0.0                          0.0
#
#                   ...  Selective Mutism_or_rule  Selective Mutism_and_rule  \
# src_subject_id    ...
# NDAR_INV007W6H7B  ...                       NaN                        NaN
# NDAR_INV00LJVZK2  ...                       NaN                        NaN
# NDAR_INV00NPMHND  ...                       NaN                        NaN
# NDAR_INV00R4TXET  ...                       NaN                        NaN
# NDAR_INV00U4FTRU  ...                       NaN                        NaN
# ...               ...                       ...                        ...
# NDAR_INVZZJ3A7BK  ...                       NaN                        NaN
# NDAR_INVZZL0VA2F  ...                       NaN                        NaN
# NDAR_INVZZLZCKAY  ...                       NaN                        NaN
# NDAR_INVZZZ2ALR6  ...                       NaN                        NaN
# NDAR_INVZZZNB0XC  ...                       NaN                        NaN
#
#                   Specific Phobia_or_rule  Specific Phobia_and_rule  \
# src_subject_id
# NDAR_INV007W6H7B                      0.0                       0.0
# NDAR_INV00LJVZK2                      0.0                       0.0
# NDAR_INV00NPMHND                      1.0                       1.0
# NDAR_INV00R4TXET                      0.0                       0.0
# NDAR_INV00U4FTRU                      0.0                       0.0
# ...                                   ...                       ...
# NDAR_INVZZJ3A7BK                      1.0                       1.0
# NDAR_INVZZL0VA2F                      0.0                       0.0
# NDAR_INVZZLZCKAY                      1.0                       1.0
# NDAR_INVZZZ2ALR6                      1.0                       1.0
# NDAR_INVZZZNB0XC                      0.0                       0.0
#
#                   Binge-Eating Disorder_or_rule  \
# src_subject_id
# NDAR_INV007W6H7B                            NaN
# NDAR_INV00LJVZK2                            NaN
# NDAR_INV00NPMHND                            NaN
# NDAR_INV00R4TXET                            NaN
# NDAR_INV00U4FTRU                            NaN
# ...                                         ...
# NDAR_INVZZJ3A7BK                            NaN
# NDAR_INVZZL0VA2F                            NaN
# NDAR_INVZZLZCKAY                            NaN
# NDAR_INVZZZ2ALR6                            NaN
# NDAR_INVZZZNB0XC                            NaN
#
#                   Binge-Eating Disorder_and_rule  Anorexia Nervosa_or_rule  \
# src_subject_id
# NDAR_INV007W6H7B                             0.0                       NaN
# NDAR_INV00LJVZK2                             0.0                       NaN
# NDAR_INV00NPMHND                             0.0                       NaN
# NDAR_INV00R4TXET                             0.0                       NaN
# NDAR_INV00U4FTRU                             0.0                       NaN
# ...                                          ...                       ...
# NDAR_INVZZJ3A7BK                             0.0                       NaN
# NDAR_INVZZL0VA2F                             0.0                       NaN
# NDAR_INVZZLZCKAY                             0.0                       NaN
# NDAR_INVZZZ2ALR6                             0.0                       NaN
# NDAR_INVZZZNB0XC                             0.0                       NaN
#
#                   Anorexia Nervosa_and_rule  Bulimia Nervosa_or_rule  \
# src_subject_id
# NDAR_INV007W6H7B                        0.0                      NaN
# NDAR_INV00LJVZK2                        0.0                      NaN
# NDAR_INV00NPMHND                        0.0                      NaN
# NDAR_INV00R4TXET                        0.0                      NaN
# NDAR_INV00U4FTRU                        0.0                      NaN
# ...                                     ...                      ...
# NDAR_INVZZJ3A7BK                        0.0                      NaN
# NDAR_INVZZL0VA2F                        0.0                      NaN
# NDAR_INVZZLZCKAY                        0.0                      NaN
# NDAR_INVZZZ2ALR6                        0.0                      NaN
# NDAR_INVZZZNB0XC                        0.0                      NaN
#
#                   Bulimia Nervosa_and_rule
# src_subject_id
# NDAR_INV007W6H7B                       0.0
# NDAR_INV00LJVZK2                       0.0
# NDAR_INV00NPMHND                       0.0
# NDAR_INV00R4TXET                       0.0
# NDAR_INV00U4FTRU                       0.0
# ...                                    ...
# NDAR_INVZZJ3A7BK                       0.0
# NDAR_INVZZL0VA2F                       0.0
# NDAR_INVZZLZCKAY                       0.0
# NDAR_INVZZZ2ALR6                       0.0
# NDAR_INVZZZNB0XC                       0.0
#
# [7188 rows x 44 columns]

# %%
for diagnosis in subindicators_table['Diagnosis'].unique():
    if diagnosis == 'Bipolar I Disorder':
        diagnosis = 'Bipolar Disorder'
    if diagnosis == 'Bipolar II Disorder':
        continue
    print(diagnosis)
    # abcd_data
    col = f'{diagnosis}'
    n_true = len(abcd_data[abcd_data[col] == 1.0])
    n_false = len(abcd_data[abcd_data[col] == 0.0])
    n_nan = len(abcd_data[abcd_data[col].isna()])
    print(f'  abcd_data:           {n_true:5d} of {n_true + n_false:5d} positive ({100 * n_true/(n_true + n_false + 1e-10):.3f} %). {n_nan:5d} NaN values.')
    # new code data
    col = f'{diagnosis}_or_rule'
    n_true = len(binary_diagnoses_2[binary_diagnoses_2[col] == 1.0])
    n_false = len(binary_diagnoses_2[binary_diagnoses_2[col] == 0.0])
    n_nan = len(binary_diagnoses_2[binary_diagnoses_2[col].isna()])
    print(f'  binary_diagnoses_2:  {n_true:5d} of {n_true + n_false:5d} positive ({100 * n_true/(n_true + n_false + 1e-10):.3f} %). {n_nan:5d} NaN values.')
# Out:
# Other Specified Neurodevelopmental Disorder Autism Spectrum Disorder
#   abcd_data:            1965 of  7087 positive (27.727 %).   101 NaN values.
#   binary_diagnoses_2:   1965 of  7087 positive (27.727 %).   101 NaN values.
# Major Depressive Disorder
#   abcd_data:             340 of  7067 positive (4.811 %).   121 NaN values.
#   binary_diagnoses_2:    340 of  7067 positive (4.811 %).   121 NaN values.
# Persistent Depressive Disorder (Dysthymia)
#   abcd_data:              15 of  7066 positive (0.212 %).   122 NaN values.
#   binary_diagnoses_2:     15 of  7066 positive (0.212 %).   122 NaN values.
# Bipolar Disorder
#   abcd_data:             517 of  7072 positive (7.311 %).   116 NaN values.
#   binary_diagnoses_2:    517 of  7072 positive (7.311 %).   116 NaN values.
# Psychotic Symptoms
#   abcd_data:             189 of  7098 positive (2.663 %).    90 NaN values.
#   binary_diagnoses_2:    189 of  7098 positive (2.663 %).    90 NaN values.
# ADHD
#   abcd_data:            1356 of  7089 positive (19.128 %).    99 NaN values.
#   binary_diagnoses_2:   1356 of  7089 positive (19.128 %).    99 NaN values.
# Oppositional Defiant Disorder
#   abcd_data:            1012 of  7089 positive (14.276 %).    99 NaN values.
#   binary_diagnoses_2:   1012 of  7089 positive (14.276 %).    99 NaN values.
# Conduct Disorder
#   abcd_data:             190 of  7089 positive (2.680 %).    99 NaN values.
#   binary_diagnoses_2:    190 of  7089 positive (2.680 %).    99 NaN values.
# PTSD
#   abcd_data:             142 of  7087 positive (2.004 %).   101 NaN values.
#   binary_diagnoses_2:    142 of  7087 positive (2.004 %).   101 NaN values.
# Obsessive Compulsive Disorder
#   abcd_data:             662 of  7087 positive (9.341 %).   101 NaN values.
#   binary_diagnoses_2:    662 of  7087 positive (9.341 %).   101 NaN values.
# Sleep Problems
#   abcd_data:            1603 of  7082 positive (22.635 %).   106 NaN values.
#   binary_diagnoses_2:   1603 of  7082 positive (22.635 %).   106 NaN values.
# Suicide Tendency
#   abcd_data:            1360 of  7072 positive (19.231 %).   116 NaN values.
#   binary_diagnoses_2:   1360 of  7072 positive (19.231 %).   116 NaN values.
# Generalized Anxiety Disorder
#   abcd_data:             371 of  7069 positive (5.248 %).   119 NaN values.
#   binary_diagnoses_2:    371 of  7069 positive (5.248 %).   119 NaN values.
# Social Anxiety Disorder
#   abcd_data:             385 of  7068 positive (5.447 %).   120 NaN values.
#   binary_diagnoses_2:    385 of  7068 positive (5.447 %).   120 NaN values.
# Panic Disorder
#   abcd_data:              19 of  7087 positive (0.268 %).   101 NaN values.
#   binary_diagnoses_2:     19 of  7087 positive (0.268 %).   101 NaN values.
# Agoraphobia
#   abcd_data:              42 of  4541 positive (0.925 %).  2647 NaN values.
#   binary_diagnoses_2:     42 of  4541 positive (0.925 %).  2647 NaN values.
# Separation Anxiety Disorder
#   abcd_data:             705 of  7096 positive (9.935 %).    92 NaN values.
#   binary_diagnoses_2:    705 of  7096 positive (9.935 %).    92 NaN values.
# Selective Mutism
#   abcd_data:               0 of     0 positive (0.000 %).  7188 NaN values.
#   binary_diagnoses_2:      0 of     0 positive (0.000 %).  7188 NaN values.
# Specific Phobia
#   abcd_data:            1977 of  7087 positive (27.896 %).   101 NaN values.
#   binary_diagnoses_2:   1977 of  7087 positive (27.896 %).   101 NaN values.
# Binge-Eating Disorder
#   abcd_data:              52 of    52 positive (100.000 %).  7136 NaN values.
#   binary_diagnoses_2:     52 of    52 positive (100.000 %).  7136 NaN values.
# Anorexia Nervosa
#   abcd_data:               2 of     2 positive (100.000 %).  7186 NaN values.
#   binary_diagnoses_2:      2 of     2 positive (100.000 %).  7186 NaN values.
# Bulimia Nervosa
#   abcd_data:               3 of     3 positive (100.000 %).  7185 NaN values.
#   binary_diagnoses_2:      3 of     3 positive (100.000 %).  7185 NaN values.

# %%
new_abcd_data = pd.read_csv(PROCESSED_DATA_DIR / 'abcd_data.csv')

# %%
for diagnosis in subindicators_table['Diagnosis'].unique():
    if diagnosis == 'Bipolar I Disorder':
        diagnosis = 'Bipolar Disorder'
    if diagnosis == 'Bipolar II Disorder':
        continue
    print(diagnosis)
    # abcd_data
    col = f'{diagnosis}'
    n_true = len(new_abcd_data[new_abcd_data[col] == 1.0])
    n_false = len(new_abcd_data[new_abcd_data[col] == 0.0])
    n_nan = len(new_abcd_data[new_abcd_data[col].isna()])
    print(f'  new_abcd_data:       {n_true:5d} of {n_true + n_false:5d} positive ({100 * n_true/(n_true + n_false + 1e-10):.3f} %). {n_nan:5d} NaN values.')
    # new code data
    col = f'{diagnosis}_or_rule'
    n_true = len(binary_diagnoses_2[binary_diagnoses_2[col] == 1.0])
    n_false = len(binary_diagnoses_2[binary_diagnoses_2[col] == 0.0])
    n_nan = len(binary_diagnoses_2[binary_diagnoses_2[col].isna()])
    print(f'  binary_diagnoses_2:  {n_true:5d} of {n_true + n_false:5d} positive ({100 * n_true/(n_true + n_false + 1e-10):.3f} %). {n_nan:5d} NaN values.')
# Out:
# Other Specified Neurodevelopmental Disorder Autism Spectrum Disorder
#   new_abcd_data:        1965 of  7087 positive (27.727 %).   101 NaN values.
#   binary_diagnoses_2:   1965 of  7087 positive (27.727 %).   101 NaN values.
# Major Depressive Disorder
#   new_abcd_data:         340 of  7067 positive (4.811 %).   121 NaN values.
#   binary_diagnoses_2:    340 of  7067 positive (4.811 %).   121 NaN values.
# Persistent Depressive Disorder (Dysthymia)
#   new_abcd_data:          15 of  7066 positive (0.212 %).   122 NaN values.
#   binary_diagnoses_2:     15 of  7066 positive (0.212 %).   122 NaN values.
# Bipolar Disorder
#   new_abcd_data:         517 of  7072 positive (7.311 %).   116 NaN values.
#   binary_diagnoses_2:    517 of  7072 positive (7.311 %).   116 NaN values.
# Psychotic Symptoms
#   new_abcd_data:         189 of  7098 positive (2.663 %).    90 NaN values.
#   binary_diagnoses_2:    189 of  7098 positive (2.663 %).    90 NaN values.
# ADHD
#   new_abcd_data:        1356 of  7089 positive (19.128 %).    99 NaN values.
#   binary_diagnoses_2:   1356 of  7089 positive (19.128 %).    99 NaN values.
# Oppositional Defiant Disorder
#   new_abcd_data:        1012 of  7089 positive (14.276 %).    99 NaN values.
#   binary_diagnoses_2:   1012 of  7089 positive (14.276 %).    99 NaN values.
# Conduct Disorder
#   new_abcd_data:         190 of  7089 positive (2.680 %).    99 NaN values.
#   binary_diagnoses_2:    190 of  7089 positive (2.680 %).    99 NaN values.
# PTSD
#   new_abcd_data:         142 of  7087 positive (2.004 %).   101 NaN values.
#   binary_diagnoses_2:    142 of  7087 positive (2.004 %).   101 NaN values.
# Obsessive Compulsive Disorder
#   new_abcd_data:         662 of  7087 positive (9.341 %).   101 NaN values.
#   binary_diagnoses_2:    662 of  7087 positive (9.341 %).   101 NaN values.
# Sleep Problems
#   new_abcd_data:        1603 of  7082 positive (22.635 %).   106 NaN values.
#   binary_diagnoses_2:   1603 of  7082 positive (22.635 %).   106 NaN values.
# Suicide Tendency
#   new_abcd_data:        1360 of  7072 positive (19.231 %).   116 NaN values.
#   binary_diagnoses_2:   1360 of  7072 positive (19.231 %).   116 NaN values.
# Generalized Anxiety Disorder
#   new_abcd_data:         371 of  7069 positive (5.248 %).   119 NaN values.
#   binary_diagnoses_2:    371 of  7069 positive (5.248 %).   119 NaN values.
# Social Anxiety Disorder
#   new_abcd_data:         385 of  7068 positive (5.447 %).   120 NaN values.
#   binary_diagnoses_2:    385 of  7068 positive (5.447 %).   120 NaN values.
# Panic Disorder
#   new_abcd_data:          19 of  7087 positive (0.268 %).   101 NaN values.
#   binary_diagnoses_2:     19 of  7087 positive (0.268 %).   101 NaN values.
# Agoraphobia
#   new_abcd_data:          42 of  4541 positive (0.925 %).  2647 NaN values.
#   binary_diagnoses_2:     42 of  4541 positive (0.925 %).  2647 NaN values.
# Separation Anxiety Disorder
#   new_abcd_data:         705 of  7096 positive (9.935 %).    92 NaN values.
#   binary_diagnoses_2:    705 of  7096 positive (9.935 %).    92 NaN values.
# Selective Mutism
#   new_abcd_data:           0 of     0 positive (0.000 %).  7188 NaN values.
#   binary_diagnoses_2:      0 of     0 positive (0.000 %).  7188 NaN values.
# Specific Phobia
#   new_abcd_data:        1977 of  7087 positive (27.896 %).   101 NaN values.
#   binary_diagnoses_2:   1977 of  7087 positive (27.896 %).   101 NaN values.
# Binge-Eating Disorder
#   new_abcd_data:          52 of    52 positive (100.000 %).  7136 NaN values.
#   binary_diagnoses_2:     52 of    52 positive (100.000 %).  7136 NaN values.
# Anorexia Nervosa
#   new_abcd_data:           2 of     2 positive (100.000 %).  7186 NaN values.
#   binary_diagnoses_2:      2 of     2 positive (100.000 %).  7186 NaN values.
# Bulimia Nervosa
#   new_abcd_data:           3 of     3 positive (100.000 %).  7185 NaN values.
#   binary_diagnoses_2:      3 of     3 positive (100.000 %).  7185 NaN values.
